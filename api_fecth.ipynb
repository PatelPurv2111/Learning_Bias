# %%
import requests
API_KEY = "cf1bf90435c74e7ab82fa39346c5c326"
url=f"https://newsapi.org/v2/top-headlines?country=us&apiKey={API_KEY}"
response = requests.get(url)
data = response.json()
articles = data['articles']
for article in articles:
    print(article['title'])
# Out:
# Nepal election 2026 results - follow live - BBC
# Raiders will trade for Bills CB Taron Johnson - NBC Sports
# China consumer inflation hits three-year high as producer deflation eases - CNBC
# Albert Breer’s Pre-Free Agency Takeaways: Why Linemen Could Receive ‘Wow’ Contracts - Sports Illustrated
# 2026 Writers Guild Awards Winners List - The Hollywood Reporter
# The Long-Feared Persian Gulf Oil Squeeze Is Upon Us - WSJ
# Microsoft's CEO to Xbox: We will "always" invest in gaming. - Windows Central
# Sinking Iran’s Frigate IRIS Dena and the Law of Naval Warfare - Just Security
# Superconductivity controlled by a built-in light-confining cavity - Phys.org
# Scoop: U.S. dismayed by Israel's Iran fuel strikes, sources say - Axios
# NFL free agency 2026 live updates: Rumors, trades, signings, latest news ahead of legal tampering period - CBS Sports
# Seventh US service member killed in Iran war after being wounded in attack in Saudi Arabia - CNN
# ...
